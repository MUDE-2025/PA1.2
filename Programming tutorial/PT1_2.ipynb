# %% [markdown]
# # Programming tutorial 1.2
#
# *[CEGM1000 MUDE](http://mude.citg.tudelft.nl/)*
#
# *Written by: `Berend Bouvy`*

# %% [markdown]
# ## Introduction
#
# During these programming tutorials, we go over the basic concepts of programming in Python. The programming tutorials will be held during the first hours of the question hours on Tuesday and they are not mandatory. During MUDE you will be provided with a lot of jupyter notebooks, such as this one, to help you solve engineering problems using Python. Most of these notebooks will contain fill-in-the-blank type of coding. During these programming tutorials, however, we will build the code from the ground up in a classroom setting, allowing for more interaction and hands-on learning.
#
# The goal of these sessions is to provide you with the right mindset and tools to tackle programming challenges effectively. We encourage you to ask questions and provide us with additional topics you would like to see covered in future tutorials.

# %% [markdown]
# ### Useful tools
#
# During coding, you will often need to look up how certain functions work. There are several useful tools to help you with this:
# - The [Python documentation](https://docs.python.org/3/) or library documentation such as [NumPy](https://numpy.org/doc/stable/) and [Pandas](https://pandas.pydata.org/pandas-docs/stable/) are great resources.
# - AI tools like [ChatGPT](https://chat.openai.com/) and [Copilot](https://github.com/features/copilot).
# - Online forums and communities such as [Stack Overflow](https://stackoverflow.com/).

# %% [markdown]
# ## Components of code
#
# 1. **Variables**: Used to store data values. In Python, you don't need to declare the type of a variable beforehand.
#    ```python
#    x = 5
#    y = "Hello"
#    ```
#
# 2. **Data Types**: Python has various data types including integers, floats, strings, lists, tuples, and dictionaries.
#    ```python
#    a = 10          # Integer
#    b = 3.14        # Float
#    c = "Hello"     # String
#    d = [1, 2, 3]   # List
#    e = (1, 2, 3)   # Tuple
#    f = {"key": "value"}  # Dictionary
#    ```
#
# 3. **Operators**: Used to perform operations on variables and values. Python supports arithmetic, comparison, logical, and bitwise operators.
#    ```python
#    sum = x + y
#    is_equal = (x == y)
#    ```
#
# 4. **Control Structures**: Used to control the flow of execution in a program. This includes conditional statements (if-else) and loops (for, while).
#    ```python
#    if x > y:
#        print("x is greater than y")
#    else:
#        print("y is greater than or equal to x")
#
#    for i in range(5):
#        print(i)
#    ```
#
# 5. **Functions**: Blocks of reusable code that perform a specific task. Functions can take inputs (parameters) and return outputs.
#    ```python
#    def add(a, b):
#        return a + b
#    ```
#
# 6. **Modules**: Files containing Python code that can be imported and used in other Python programs. This allows for code reusability and organization.
#    ```python
#    import math
#    result = math.sqrt(16)
#    ```
#
# 7. **Comments**: Used to explain code and make it more readable. Comments are ignored by the Python interpreter.
#    ```python
#    # This is a single-line comment
#    ```

# %% [markdown]
# <div style="background-color:#AABAB2; color: black; width:90%; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
#
# $\text{Task 1.1:}$
#
# We will first take a look at the list object. We will explore its properties and methods. First, we start by creating a list with the numbers 1 to 5 and then we will perform some basic operations on it and briefly discuss indexing and slicing.

# %%
# Create a list
my_list = [1, 2, 3, 4, 5]
print(my_list)

# Access an item
print(my_list[0])

# Access last item
print(my_list[-1])

# Slice the list
print(my_list[1:4])

# Append an item
my_list.append(6)
print(my_list)

# Remove an item
my_list.remove(3)
print(my_list)

# Sort the list in descending order
my_list.sort(reverse=True)
print(my_list)

# Get the length of the list
print(len(my_list))
# Out:
# [1, 2, 3, 4, 5]
# 1
# 5
# [2, 3, 4]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 4, 5, 6]
# [6, 5, 4, 2, 1]
# 5

# %% [markdown]
# <div style="background-color:#AABAB2; color: black; width:90%; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
#
# $\text{Task 1.2:}$
#
# The second task involves exploring the dictionary object. We will create a dictionary to store the names and ages of some people. Then, we will perform some basic operations on the dictionary and discuss key-value pairs.

# %%
# Create a dictionary
ages = {
    "Alice": 30,
    "Bob": 25,
    "Charlie": 35
}

# Iterate through the dictionary
for name in ages:
    print(f"{name} is {ages[name]} years old.")

# Add gender information
ages_gender = {
    "Alice": {"age": 30, "gender": "female"},
    "Bob": {"age": 25, "gender": "male"},
    "Charlie": {"age": 35, "gender": "male"}
}

# Iterate through the new dictionary
for name in ages_gender:
    print(f"{name} is {ages_gender[name]['age']} years old and is {ages_gender[name]['gender']}.")
    
# Find all males younger than 30
for name in ages_gender:
    if ages_gender[name]['gender'] == 'male' and ages_gender[name]['age'] < 30:
        print(f"{name} is a male younger than 30.")
# Out:
# Alice is 30 years old.
# Bob is 25 years old.
# Charlie is 35 years old.
# Alice is 30 years old and is female.
# Bob is 25 years old and is male.
# Charlie is 35 years old and is male.
# Bob is a male younger than 30.

# %% [markdown]
# <div style="background-color:#AABAB2; color: black; width:90%; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
#
# $\text{Task 1.3:}$
#
# if/elif/else statements. We will write a program that checks the age of a person and prints whether they are a child, teenager, or adult.

# %%
my_age = 20
my_gender = "male"

if my_age < 13:
    if my_gender == "male":
        print("You are a boy.")
    else:
        print("You are a girl.")
elif my_age < 20:
    print("You are a teenager.")
else:
    print("You are an adult.")

# %% [markdown]
# <div style="background-color:#AABAB2; color: black; width:90%; vertical-align: middle; padding:15px; margin: 10px; border-radius: 10px">
# <p>
#
# $\text{Task 1.4:}$
#
# The final structure we will investigate is the for loop. For loops allow us to iterate over a sequence (like a list or a string) and perform an action for each item in that sequence. We will create a simple program that finds the maximum value in a list of numbers.

# %%
for i in [1, 2, 3, 4, 5]:
    print(i)

for i in [1, 2, 3, 4, 5]:
    print(i*2)

for i in 'Hello':
    print(i)

for i, j in enumerate(['a', 'b', 'c']):
    print(f"the index is {i} and the value is {j}")
    
my_list = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
current_max = my_list[0]
for num in my_list:
    if num > current_max:
        print(f"New maximum found: {num}")
        current_max = num
print(f"The maximum value in the list is {current_max}")
# Out:
# 1
# 2
# 3
# 4
# 5
# 2
# 4
# 6
# 8
# 10
# H
# e
# l
# l
# o
# the index is 0 and the value is a
# the index is 1 and the value is b
# the index is 2 and the value is c
# New maximum found: 4
# New maximum found: 5
# New maximum found: 9
# The maximum value in the list is 9

# %% [markdown]
# <div style="margin-top: 50px; padding-top: 20px; border-top: 1px solid #ccc;">
#   <div style="display: flex; justify-content: flex-end; gap: 20px; align-items: center;">
#     <a rel="MUDE" href="http://mude.citg.tudelft.nl/">
#       <img alt="MUDE" style="width:100px; height:auto;" src="https://gitlab.tudelft.nl/mude/public/-/raw/main/mude-logo/MUDE_Logo-small.png" />
#     </a>
#     <a rel="TU Delft" href="https://www.tudelft.nl/en/ceg">
#       <img alt="TU Delft" style="width:100px; height:auto;" src="https://gitlab.tudelft.nl/mude/public/-/raw/main/tu-logo/TU_P1_full-color.png" />
#     </a>
#     <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">
#       <img alt="Creative Commons License" style="width:88px; height:auto;" src="https://i.creativecommons.org/l/by/4.0/88x31.png" />
#     </a>
#   </div>
#   <div style="font-size: 75%; margin-top: 10px; text-align: right;">
#     &copy; Copyright 2025 <a rel="MUDE" href="http://mude.citg.tudelft.nl/">MUDE</a> TU Delft.
#     This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">CC BY 4.0 License</a>.
#   </div>
# </div>
